# %% [markdown]
# <a href="https://colab.research.google.com/github/selvaarakshun/selvaarakshun/blob/main/gpt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from huggingface_hub import login

# Replace with your token
login(token="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")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM # Import necessary classes

tokenizer = AutoTokenizer.from_pretrained("gpt2")
model = AutoModelForCausalLM.from_pretrained("gpt2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# The cache directory location where models are stored by default
from transformers import file_utils
print(file_utils.default_cache_path)
# Out:
# /root/.cache/huggingface/hub

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from transformers import file_utils

# Get the default cache directory path
cache_dir = file_utils.default_cache_path

# Load the tokenizer and model by name or a subdirectory within cache_dir
tokenizer = GPT2Tokenizer.from_pretrained("gpt2", cache_dir=cache_dir)  # Specify the model name and cache_dir
model = GPT2LMHeadModel.from_pretrained("gpt2", cache_dir=cache_dir) # Specify the model name and cache_dir

# %%
input_text = "Once upon a time"
inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**inputs, max_length=50)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time, the world was a place of great beauty and great danger. The world was a place of great danger, and the world was a place of great danger. The world was a place of great danger, and the world was a

# %%
input_text = "Micro Diamond"
inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**inputs, max_length=50)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Micro Diamonds
#
# The Diamonds are a unique type of diamond that is used in the production of jewelry. They are made from a variety of materials, including diamond, copper, and silver.
#
# Diamonds are made from a variety of

# %%
input_text = "Micro Diamond"
inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**inputs, max_length=50)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Micro Diamonds
#
# The Diamonds are a unique type of diamond that is used in the production of jewelry. They are made from a variety of materials, including diamond, copper, and silver.
#
# Diamonds are made from a variety of

# %%
input_text = "INformation "
inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**inputs, max_length=50)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# INformation Technology, Inc.
#
# The following is a list of the companies that have been listed as having been listed as having been listed as having been listed as having been listed as having been listed as having been listed as having been listed as having
